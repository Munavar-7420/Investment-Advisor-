# %% [markdown]
# # Evaluation 1

# %% [markdown]
# Q-1 What does sequence mean and which three types of data fall into this
# category? (2 Marks)

# %% [markdown]
# --- There are three data types which fall in the sequence category there are List,Tuple and Dictonories. Sequence mean the datea which we are inserting are should be in sequence so that it will be easy to find.

# %% [markdown]
# Q-2 Consider a list (list = [ ]).You can perform the following commands: (10 Marks)
# insert i e: Insert integer at the position.
# print: Print the list.
# remove i.e: Delete the first occurrence of integer.
# append i.e: Insert integer at the end of the list.
# sort: Sort the list.
# pop: Pop the last element from the list.
# reverse: Reverse the list.
# Initialize your list and read in the value followed by lines of commands where each command will be of
# the types listed above. Iterate through each command in order and perform the corresponding
# operation on your list.
#
# Example
#
# N = 4
#
# Append 1
#
# Append 2
#
# Insert 3 1
#
# Print
# Output: [1, 3, 2]

# %%
N=[1,3,5,7]
N.append(10)
N.remove(5)
N.insert(3,6)
print("output :",N)
# Out:
# output : [1, 3, 7, 6, 10]

# %% [markdown]
# Q-3 Write a program in Python to remove duplicate items from a list. (10 Marks)
# Input: [2,3,4,5,2,6,3,2]
# Output: [2,3,4,5,6]

# %%
Input = [2,3,4,5,2,6,3,2]
Input.sort()
print("output:",Input)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [102], in <cell line: 3>()
#       1 Input = [2,3,4,5,2,6,3,2]
#       2 Input.sort()
# ----> 3 Input.delete[1]
#       4 print("output:",Input)
#
# AttributeError: 'list' object has no attribute 'delete'

# %% [markdown]
# Q-4 Check if the given string contains all numeric values if it contains print True otherwise print False using
# string operation.(4 Marks)
# Example input: ‘’53515’’, ‘’543acd45’’
# Output : True , False

# %%
Input= "123"
Input.isnumeric()
# Out:
# True

# %%
N="1qws3344"
N.isnumeric()
# Out:
# False

# %% [markdown]
# Q-5 Here it is given strings, store the given string into variable and change it into the expected results
# performing various string operations and print the result.(10 Marks)
# Sample String : 'abc', 'xyz' ,'pQr'
# Expected Result : 'ABC_Xyz_pqr'

# %%
str1='abc'
str1=str1.upper()
str1
str2='xyz'
str2=str2.capitalize()
str3='pQr'
str3=str3.capitalize()
print(str1,"_",str2,"_",str3)
# Out:
# ABC _ Xyz _ Pqr

# %% [markdown]
# Q-6 Below is given a string, return the first occurrence of Substring if found if not found return -1 perform
# this using only string operation.(5 Marks)
# Given string = “ Masai data Analytics Course is the best Course”, substring1 = ‘’Course”, substring2 = ‘was’
# Example input: ‘’ this life is my life” , substring1 = “life” ,substring2 = an
# Output : 5, -1

# %%
string = " Masai data Analytics Course is the best Course"
substring1 = "Course"
substring2 = "was"
string.find(substring1) , string.find(substring2)
# Out:
# (22, -1)

# %% [markdown]
# Q-7 find the second occurrence of substring “aba” in the given string “aabaccaabcabaaabac” (5 Marks)
# Example input : ‘’Banana’’, ‘’na’
# Output : 4

# %%
s= "aabaccaabcabaaabac"
s.find("aba",2)
# Out:
# 10

# %% [markdown]
# Q-8 Write a Python program to get a string from a given string where all occurrences of its first char have
# been changed to '$' , except the first char itself. (10 Marks)
#
# Sample String : 'restart'
#
# Expected Result : 'resta$t'

# %%
s= 'restart'
s[5] = ''$''
# Out:
#   Input In [100]
#     s[5]= ''$''
#             ^
# SyntaxError: invalid syntax

# %% [markdown]
# Q-9 Write a Python program to add an item in a tuple. (5 Marks)
# Input : t = (4, 6, 2, 8, 3, 1) adding items : 5, 20, 25
# Output t = ( 4, 6, 2, 8, 3, 1, 5, 20, 25)

# %%
t= (4, 6, 2, 8, 3, 1) 
t1=(5,20,25)
t2=t+t1
t2
# Out:
# (4, 6, 2, 8, 3, 1, 5, 20, 25)

# %% [markdown]
# Q-10 Write a Python program to check whether an element exists within a tuple (5 Marks)
# Input : to check r and 5 present in given tuple, tuplex = ("w", 3, "r", "e", "s", "o", "u", "r", "c", "e")
# Output: True , False

# %%
tuplex = ("w", 3, "r", "e", "s", "o", "u", "r", "c", "e")
"r" in tuplex, 5 in tuplex
# Out:
# (True, False)

# %% [markdown]
# Q-11 Write a Python program to convert a tuple to a string. (10 Marks)
# Input: tup = ('e', 'x', 'e', 'r', 'c', 'i', 's', 'e', 's')
# Output: exercises

# %%
tup = ('e', 'x', 'e', 'r', 'c', 'i', 's', 'e', 's')
tup.
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [78], in <cell line: 2>()
#       1 tup = ('e', 'x', 'e', 'r', 'c', 'i', 's', 'e', 's')
# ----> 2 tup.join( )
#
# AttributeError: 'tuple' object has no attribute 'join'

# %% [markdown]
# Q-12 Make a tuple from the given values :10, 5, 11, 15, 13,11, 20 and print the sorted tuple. (10 Marks)
# Example Input: 2,5,3,8,7,1
# Output: ( ‘1’, ‘2’, ‘3’, ‘5’, ‘7’, ‘8’)

# %%
tuple1=(10, 5, 11, 15, 13,11, 20)
tuple1
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [51], in <cell line: 2>()
#       1 tuple1=(10, 5, 11, 15, 13,11, 20)
# ----> 2 tuple1.isorder()
#
# AttributeError: 'tuple' object has no attribute 'isorder'

# %% [markdown]
# Q-13 Write a Python script to add a key to a dictionary. (4 Marks)
# Sample Dictionary : {0: 10, 1: 20}
# Expected Result : {0: 10, 1: 20, 2: 30}

# %%
Dictionary = {0: 10, 1: 20}
Dict1={2:30}
Dictionary|Dict1
# Out:
# {0: 10, 1: 20, 2: 30}

# %% [markdown]
# Q-14 Write a Python script to concatenate the following dictionaries to create a new one.
# (10 Marks)
# Sample Dictionary :
# dic1={1:10, 2:20}
# dic2={3:30, 4:40}
# dic3={5:50,6:60}
# Expected Result : {1: 10, 2: 20, 3: 30, 4: 40, 5: 50, 6: 60}

# %%
dic1={1:10, 2:20} 
dic2={3:30, 4:40} 
dic3={5:50,6:60}
dic4=dic1|dic2|dic3
dic4
# Out:
# {1: 10, 2: 20, 3: 30, 4: 40, 5: 50, 6: 60}
